# %%
import pandas as pd
from scipy.spatial.distance import cosine

# %%
data = pd.read_csv('raw_data3.csv')
#data.head()
d1 = data.ix[:, 0] 
d2 = data.ix[:, 6:11]

# %%
d = pd.concat([d1, d2], axis=1)

# %%
# --- Start Item Based Recommendations --- #
# Drop any column named "user"
data_germany = d.drop('studentid', 1)

# %%
data_ibs = pd.DataFrame(index=data_germany['disciplineid'],columns=data_germany['disciplineid'])

# %%
data_ibs
# Out:
# disciplineid 11   31   49   52   53   163  65   424  491  524  ...  2033 2075  \
# disciplineid                                                   ...
# 11            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 31            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 49            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 52            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 53            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 163           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 65            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 424           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 491           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# 524           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# ...
